# %%
import model_universe_2d as u
import matplotlib.pyplot as plt

# %% [markdown]
# <small>
# load default universe
# </small>

# %%
# density fields - aviles's parameters
rho_x = u.rho_x  # tracer density field 
rho_R = u.rho_R # smoothed density tracer field
delta_x = u.delta_x # overdensity of tracer field
delta_R = u.delta_R # overdensity of downsampled tracer field
m = u.m # mark
delta_M = u.delta_M # marked density field

# %% [markdown]
# #### test mark parameters $R$, $p$ and $\delta*$ by varying one parameter and fixing the other two for 3-4 preset universes

# %% [markdown]
# ### testing R values

# %% [markdown]
# ##### universe 1

# %%
# different R values

rho_R = u.gaussian_filter(rho_x, R=1)
delta_x = u.overdensity_field(rho_x)
delta_R1 = u.overdensity_field(rho_R)
m1, delta_M1 = u.marked_overdensity_field(delta_x, delta_R1, delta_star=4, p=10)


rho_R = u.gaussian_filter(rho_x, R=2)
delta_x = u.overdensity_field(rho_x)
delta_R2 = u.overdensity_field(rho_R)
m2, delta_M2 = u.marked_overdensity_field(delta_x, delta_R2, delta_star=4, p=10)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R3 = u.overdensity_field(rho_R)
m3, delta_M3 = u.marked_overdensity_field(delta_x, delta_R3, delta_star=4, p=10)


rho_R = u.gaussian_filter(rho_x, R=4)
delta_x = u.overdensity_field(rho_x)
delta_R4 = u.overdensity_field(rho_R)
m4, delta_M4 = u.marked_overdensity_field(delta_x, delta_R4, delta_star=4, p=10)

rho_R = u.gaussian_filter(rho_x, R=5)
delta_x = u.overdensity_field(rho_x)
delta_R5 = u.overdensity_field(rho_R)
m5, delta_M5 = u.marked_overdensity_field(delta_x, delta_R5, delta_star=4, p=10)


# stacked overdensity plots
fig, ax = plt.subplots(1,6,figsize=(16,3), constrained_layout=True)

im0=ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
im1=ax[1].imshow(delta_R1, cmap='plasma') 
ax[1].set_title("R=1")
im2=ax[2].imshow(delta_R2, cmap='plasma') 
ax[2].set_title("R=2")
im3=ax[3].imshow(delta_R3, cmap='plasma') 
ax[3].set_title("R=3")
im4=ax[4].imshow(delta_R4, cmap='plasma') 
ax[4].set_title("R=4")
im5=ax[5].imshow(delta_R5, cmap='plasma') 
ax[5].set_title("R=5")


fig.suptitle('$R$ comparison - overdensity field')

fig.colorbar(im0, ax=ax[0], orientation='horizontal', pad=0.04)
fig.colorbar(im1, ax=ax[1], orientation='horizontal', pad=0.04)
fig.colorbar(im2, ax=ax[2], orientation='horizontal', pad=0.04)
fig.colorbar(im3, ax=ax[3], orientation='horizontal', pad=0.04)
fig.colorbar(im4, ax=ax[4], orientation='horizontal', pad=0.04)
fig.colorbar(im5, ax=ax[5], orientation='horizontal', pad=0.04)

plt.show()


# stacked mark

fig, ax = plt.subplots(1,6,figsize=(16,3), constrained_layout=True)


im0=ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
im1=ax[1].imshow(m1, cmap='plasma') 
ax[1].set_title("R=1")
im2=ax[2].imshow(m2, cmap='plasma') 
ax[2].set_title("R=2")
im3=ax[3].imshow(m3, cmap='plasma') 
ax[3].set_title("R=3")
im4=ax[4].imshow(m4, cmap='plasma') 
ax[4].set_title("R=4")
im5=ax[5].imshow(m5, cmap='plasma') 
ax[5].set_title("R=5")


fig.suptitle('$R$ comparison - mark function')

fig.colorbar(im0, ax=ax[0], orientation='horizontal', pad=0.04)
fig.colorbar(im1, ax=ax[1], orientation='horizontal', pad=0.04)
fig.colorbar(im2, ax=ax[2], orientation='horizontal', pad=0.04)
fig.colorbar(im3, ax=ax[3], orientation='horizontal', pad=0.04)
fig.colorbar(im4, ax=ax[4], orientation='horizontal', pad=0.04)
fig.colorbar(im5, ax=ax[5], orientation='horizontal', pad=0.04)

plt.show()


# stacked marked field

fig, ax = plt.subplots(1,6,figsize=(16,3), constrained_layout=True)


im0=ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
im1=ax[1].imshow(delta_M1, cmap='plasma') 
ax[1].set_title("R=1")
im2=ax[2].imshow(delta_M2, cmap='plasma') 
ax[2].set_title("R=2")
im3=ax[3].imshow(delta_M3, cmap='plasma') 
ax[3].set_title("R=3")
im4=ax[4].imshow(delta_M4, cmap='plasma') 
ax[4].set_title("R=4")
im5=ax[5].imshow(delta_M5, cmap='plasma') 
ax[5].set_title("R=5")

fig.suptitle('$R$ comparison - marked overdensity field')

fig.colorbar(im0, ax=ax[0], orientation='horizontal', pad=0.04)
fig.colorbar(im1, ax=ax[1], orientation='horizontal', pad=0.04)
fig.colorbar(im2, ax=ax[2], orientation='horizontal', pad=0.04)
fig.colorbar(im3, ax=ax[3], orientation='horizontal', pad=0.04)
fig.colorbar(im4, ax=ax[4], orientation='horizontal', pad=0.04)
fig.colorbar(im5, ax=ax[5], orientation='horizontal', pad=0.04)

plt.show()

# %% [markdown]
# comparing R values

# %% [markdown]
# ##### universe 2

# %%
# different R values
_, _, _, rho_x = u.load_universe("universe_parameters1.json")

# different R values

rho_R = u.gaussian_filter(rho_x, R=1)
delta_x = u.overdensity_field(rho_x)
delta_R1 = u.overdensity_field(rho_R)
m1, delta_M1 = u.marked_overdensity_field(delta_x, delta_R1, delta_star=4, p=10)


rho_R = u.gaussian_filter(rho_x, R=2)
delta_x = u.overdensity_field(rho_x)
delta_R2 = u.overdensity_field(rho_R)
m2, delta_M2 = u.marked_overdensity_field(delta_x, delta_R2, delta_star=4, p=10)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R3 = u.overdensity_field(rho_R)
m3, delta_M3 = u.marked_overdensity_field(delta_x, delta_R3, delta_star=4, p=10)


rho_R = u.gaussian_filter(rho_x, R=4)
delta_x = u.overdensity_field(rho_x)
delta_R4 = u.overdensity_field(rho_R)
m4, delta_M4 = u.marked_overdensity_field(delta_x, delta_R4, delta_star=4, p=10)

rho_R = u.gaussian_filter(rho_x, R=5)
delta_x = u.overdensity_field(rho_x)
delta_R5 = u.overdensity_field(rho_R)
m5, delta_M5 = u.marked_overdensity_field(delta_x, delta_R5, delta_star=4, p=10)


# stacked overdensity plots
fig, ax = plt.subplots(1,6,figsize=(16,3), constrained_layout=True)

im0=ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
im1=ax[1].imshow(delta_R1, cmap='plasma') 
ax[1].set_title("R=1")
im2=ax[2].imshow(delta_R2, cmap='plasma') 
ax[2].set_title("R=2")
im3=ax[3].imshow(delta_R3, cmap='plasma') 
ax[3].set_title("R=3")
im4=ax[4].imshow(delta_R4, cmap='plasma') 
ax[4].set_title("R=4")
im5=ax[5].imshow(delta_R5, cmap='plasma') 
ax[5].set_title("R=5")


fig.suptitle('$R$ comparison - overdensity field')

fig.colorbar(im0, ax=ax[0], orientation='horizontal', pad=0.04)
fig.colorbar(im1, ax=ax[1], orientation='horizontal', pad=0.04)
fig.colorbar(im2, ax=ax[2], orientation='horizontal', pad=0.04)
fig.colorbar(im3, ax=ax[3], orientation='horizontal', pad=0.04)
fig.colorbar(im4, ax=ax[4], orientation='horizontal', pad=0.04)
fig.colorbar(im5, ax=ax[5], orientation='horizontal', pad=0.04)

plt.savefig('R-overdensity.png')
plt.show()


# stacked mark

fig, ax = plt.subplots(1,6,figsize=(16,3), constrained_layout=True)


im0=ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
im1=ax[1].imshow(m1, cmap='plasma') 
ax[1].set_title("R=1")
im2=ax[2].imshow(m2, cmap='plasma') 
ax[2].set_title("R=2")
im3=ax[3].imshow(m3, cmap='plasma') 
ax[3].set_title("R=3")
im4=ax[4].imshow(m4, cmap='plasma') 
ax[4].set_title("R=4")
im5=ax[5].imshow(m5, cmap='plasma') 
ax[5].set_title("R=5")


fig.suptitle('$R$ comparison - mark function')

fig.colorbar(im0, ax=ax[0], orientation='horizontal', pad=0.04)
fig.colorbar(im1, ax=ax[1], orientation='horizontal', pad=0.04)
fig.colorbar(im2, ax=ax[2], orientation='horizontal', pad=0.04)
fig.colorbar(im3, ax=ax[3], orientation='horizontal', pad=0.04)
fig.colorbar(im4, ax=ax[4], orientation='horizontal', pad=0.04)
fig.colorbar(im5, ax=ax[5], orientation='horizontal', pad=0.04)

plt.savefig('R-mark.png')
plt.show()


# stacked marked field

fig, ax = plt.subplots(1,6,figsize=(16,3), constrained_layout=True)


im0=ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
im1=ax[1].imshow(delta_M1, cmap='plasma') 
ax[1].set_title("R=1")
im2=ax[2].imshow(delta_M2, cmap='plasma') 
ax[2].set_title("R=2")
im3=ax[3].imshow(delta_M3, cmap='plasma') 
ax[3].set_title("R=3")
im4=ax[4].imshow(delta_M4, cmap='plasma') 
ax[4].set_title("R=4")
im5=ax[5].imshow(delta_M5, cmap='plasma') 
ax[5].set_title("R=5")

fig.suptitle('$R$ comparison - marked overdensity field')

fig.colorbar(im0, ax=ax[0], orientation='horizontal', pad=0.04)
fig.colorbar(im1, ax=ax[1], orientation='horizontal', pad=0.04)
fig.colorbar(im2, ax=ax[2], orientation='horizontal', pad=0.04)
fig.colorbar(im3, ax=ax[3], orientation='horizontal', pad=0.04)
fig.colorbar(im4, ax=ax[4], orientation='horizontal', pad=0.04)
fig.colorbar(im5, ax=ax[5], orientation='horizontal', pad=0.04)

plt.savefig('R-marked-function.png')
plt.show()

# %% [markdown]
# ##### universe 3

# %%
# different R values
_, _, _, rho_x = u.load_universe("universe_parameters2.json")

# different R values

rho_R = u.gaussian_filter(rho_x, R=1)
delta_x = u.overdensity_field(rho_x)
delta_R1 = u.overdensity_field(rho_R)
m1, delta_M1 = u.marked_overdensity_field(delta_x, delta_R1, delta_star=4, p=10)


rho_R = u.gaussian_filter(rho_x, R=2)
delta_x = u.overdensity_field(rho_x)
delta_R2 = u.overdensity_field(rho_R)
m2, delta_M2 = u.marked_overdensity_field(delta_x, delta_R2, delta_star=4, p=10)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R3 = u.overdensity_field(rho_R)
m3, delta_M3 = u.marked_overdensity_field(delta_x, delta_R3, delta_star=4, p=10)


rho_R = u.gaussian_filter(rho_x, R=4)
delta_x = u.overdensity_field(rho_x)
delta_R4 = u.overdensity_field(rho_R)
m4, delta_M4 = u.marked_overdensity_field(delta_x, delta_R4, delta_star=4, p=10)

rho_R = u.gaussian_filter(rho_x, R=5)
delta_x = u.overdensity_field(rho_x)
delta_R5 = u.overdensity_field(rho_R)
m5, delta_M5 = u.marked_overdensity_field(delta_x, delta_R5, delta_star=4, p=10)


# stacked overdensity plots
fig, ax = plt.subplots(1,6,figsize=(16,3), constrained_layout=True)

im0=ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
im1=ax[1].imshow(delta_R1, cmap='plasma') 
ax[1].set_title("R=1")
im2=ax[2].imshow(delta_R2, cmap='plasma') 
ax[2].set_title("R=2")
im3=ax[3].imshow(delta_R3, cmap='plasma') 
ax[3].set_title("R=3")
im4=ax[4].imshow(delta_R4, cmap='plasma') 
ax[4].set_title("R=4")
im5=ax[5].imshow(delta_R5, cmap='plasma') 
ax[5].set_title("R=5")


fig.suptitle('$R$ comparison - overdensity field')

fig.colorbar(im0, ax=ax[0], orientation='horizontal', pad=0.04)
fig.colorbar(im1, ax=ax[1], orientation='horizontal', pad=0.04)
fig.colorbar(im2, ax=ax[2], orientation='horizontal', pad=0.04)
fig.colorbar(im3, ax=ax[3], orientation='horizontal', pad=0.04)
fig.colorbar(im4, ax=ax[4], orientation='horizontal', pad=0.04)
fig.colorbar(im5, ax=ax[5], orientation='horizontal', pad=0.04)


plt.show()


# stacked mark

fig, ax = plt.subplots(1,6,figsize=(16,3), constrained_layout=True)


im0=ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
im1=ax[1].imshow(m1, cmap='plasma') 
ax[1].set_title("R=1")
im2=ax[2].imshow(m2, cmap='plasma') 
ax[2].set_title("R=2")
im3=ax[3].imshow(m3, cmap='plasma') 
ax[3].set_title("R=3")
im4=ax[4].imshow(m4, cmap='plasma') 
ax[4].set_title("R=4")
im5=ax[5].imshow(m5, cmap='plasma') 
ax[5].set_title("R=5")


fig.suptitle('$R$ comparison - mark function')

fig.colorbar(im0, ax=ax[0], orientation='horizontal', pad=0.04)
fig.colorbar(im1, ax=ax[1], orientation='horizontal', pad=0.04)
fig.colorbar(im2, ax=ax[2], orientation='horizontal', pad=0.04)
fig.colorbar(im3, ax=ax[3], orientation='horizontal', pad=0.04)
fig.colorbar(im4, ax=ax[4], orientation='horizontal', pad=0.04)
fig.colorbar(im5, ax=ax[5], orientation='horizontal', pad=0.04)

plt.show()


# stacked marked field

fig, ax = plt.subplots(1,6,figsize=(16,3), constrained_layout=True)


im0=ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
im1=ax[1].imshow(delta_M1, cmap='plasma') 
ax[1].set_title("R=1")
im2=ax[2].imshow(delta_M2, cmap='plasma') 
ax[2].set_title("R=2")
im3=ax[3].imshow(delta_M3, cmap='plasma') 
ax[3].set_title("R=3")
im4=ax[4].imshow(delta_M4, cmap='plasma') 
ax[4].set_title("R=4")
im5=ax[5].imshow(delta_M5, cmap='plasma') 
ax[5].set_title("R=5")

fig.suptitle('$R$ comparison - marked overdensity field')

fig.colorbar(im0, ax=ax[0], orientation='horizontal', pad=0.04)
fig.colorbar(im1, ax=ax[1], orientation='horizontal', pad=0.04)
fig.colorbar(im2, ax=ax[2], orientation='horizontal', pad=0.04)
fig.colorbar(im3, ax=ax[3], orientation='horizontal', pad=0.04)
fig.colorbar(im4, ax=ax[4], orientation='horizontal', pad=0.04)
fig.colorbar(im5, ax=ax[5], orientation='horizontal', pad=0.04)


plt.show()

# %% [markdown]
# ##### universe 4

# %%
# different R values
_, _, _, rho_x = u.load_universe("universe_parameters3.json")

# different R values

rho_R = u.gaussian_filter(rho_x, R=1)
delta_x = u.overdensity_field(rho_x)
delta_R1 = u.overdensity_field(rho_R)
m1, delta_M1 = u.marked_overdensity_field(delta_x, delta_R1, delta_star=4, p=10)


rho_R = u.gaussian_filter(rho_x, R=2)
delta_x = u.overdensity_field(rho_x)
delta_R2 = u.overdensity_field(rho_R)
m2, delta_M2 = u.marked_overdensity_field(delta_x, delta_R2, delta_star=4, p=10)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R3 = u.overdensity_field(rho_R)
m3, delta_M3 = u.marked_overdensity_field(delta_x, delta_R3, delta_star=4, p=10)


rho_R = u.gaussian_filter(rho_x, R=4)
delta_x = u.overdensity_field(rho_x)
delta_R4 = u.overdensity_field(rho_R)
m4, delta_M4 = u.marked_overdensity_field(delta_x, delta_R4, delta_star=4, p=10)

rho_R = u.gaussian_filter(rho_x, R=5)
delta_x = u.overdensity_field(rho_x)
delta_R5 = u.overdensity_field(rho_R)
m5, delta_M5 = u.marked_overdensity_field(delta_x, delta_R5, delta_star=4, p=10)


# stacked overdensity plots
fig, ax = plt.subplots(1,6,figsize=(16,3), constrained_layout=True)

im0=ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
im1=ax[1].imshow(delta_R1, cmap='plasma') 
ax[1].set_title("R=1")
im2=ax[2].imshow(delta_R2, cmap='plasma') 
ax[2].set_title("R=2")
im3=ax[3].imshow(delta_R3, cmap='plasma') 
ax[3].set_title("R=3")
im4=ax[4].imshow(delta_R4, cmap='plasma') 
ax[4].set_title("R=4")
im5=ax[5].imshow(delta_R5, cmap='plasma') 
ax[5].set_title("R=5")


fig.suptitle('$R$ comparison - overdensity field')

fig.colorbar(im0, ax=ax[0], orientation='horizontal', pad=0.04)
fig.colorbar(im1, ax=ax[1], orientation='horizontal', pad=0.04)
fig.colorbar(im2, ax=ax[2], orientation='horizontal', pad=0.04)
fig.colorbar(im3, ax=ax[3], orientation='horizontal', pad=0.04)
fig.colorbar(im4, ax=ax[4], orientation='horizontal', pad=0.04)
fig.colorbar(im5, ax=ax[5], orientation='horizontal', pad=0.04)

plt.show()


# stacked mark

fig, ax = plt.subplots(1,6,figsize=(16,3), constrained_layout=True)


im0=ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
im1=ax[1].imshow(m1, cmap='plasma') 
ax[1].set_title("R=1")
im2=ax[2].imshow(m2, cmap='plasma') 
ax[2].set_title("R=2")
im3=ax[3].imshow(m3, cmap='plasma') 
ax[3].set_title("R=3")
im4=ax[4].imshow(m4, cmap='plasma') 
ax[4].set_title("R=4")
im5=ax[5].imshow(m5, cmap='plasma') 
ax[5].set_title("R=5")


fig.suptitle('$R$ comparison - mark function')

fig.colorbar(im0, ax=ax[0], orientation='horizontal', pad=0.04)
fig.colorbar(im1, ax=ax[1], orientation='horizontal', pad=0.04)
fig.colorbar(im2, ax=ax[2], orientation='horizontal', pad=0.04)
fig.colorbar(im3, ax=ax[3], orientation='horizontal', pad=0.04)
fig.colorbar(im4, ax=ax[4], orientation='horizontal', pad=0.04)
fig.colorbar(im5, ax=ax[5], orientation='horizontal', pad=0.04)

plt.show()


# stacked marked field

fig, ax = plt.subplots(1,6,figsize=(16,3), constrained_layout=True)


im0=ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
im1=ax[1].imshow(delta_M1, cmap='plasma') 
ax[1].set_title("R=1")
im2=ax[2].imshow(delta_M2, cmap='plasma') 
ax[2].set_title("R=2")
im3=ax[3].imshow(delta_M3, cmap='plasma') 
ax[3].set_title("R=3")
im4=ax[4].imshow(delta_M4, cmap='plasma') 
ax[4].set_title("R=4")
im5=ax[5].imshow(delta_M5, cmap='plasma') 
ax[5].set_title("R=5")

fig.suptitle('$R$ comparison - marked overdensity field')

fig.colorbar(im0, ax=ax[0], orientation='horizontal', pad=0.04)
fig.colorbar(im1, ax=ax[1], orientation='horizontal', pad=0.04)
fig.colorbar(im2, ax=ax[2], orientation='horizontal', pad=0.04)
fig.colorbar(im3, ax=ax[3], orientation='horizontal', pad=0.04)
fig.colorbar(im4, ax=ax[4], orientation='horizontal', pad=0.04)
fig.colorbar(im5, ax=ax[5], orientation='horizontal', pad=0.04)


plt.show()

# %% [markdown]
# ### mark parameter $p$

# %% [markdown]
# ##### universe 1

# %%
# different p values

_, _, _, rho_x = u.load_universe("universe_parameters.json")

rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m1, delta_M1 = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=6)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m2, delta_M2 = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=7)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m3, delta_M3 = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=8)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m4, delta_M4 = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=9)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m5, delta_M5 = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=10)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m6, delta_M6 = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=11)


# stacked overdensity plots

# stacked mark

fig, ax = plt.subplots(1,7,figsize=(17,3), constrained_layout=True)

im0=ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
im1=ax[1].imshow(m1, cmap='plasma') 
ax[1].set_title("p=6")
im2=ax[2].imshow(m2, cmap='plasma') 
ax[2].set_title("p=7")
im3=ax[3].imshow(m3, cmap='plasma') 
ax[3].set_title("p=8")
im4=ax[4].imshow(m4, cmap='plasma') 
ax[4].set_title("p=9")
im5=ax[5].imshow(m5, cmap='plasma') 
ax[5].set_title("p=10")
im6=ax[6].imshow(m6, cmap='plasma') 
ax[6].set_title("p=11")

fig.suptitle("$p$ comparison - mark function")


fig.colorbar(im0, ax=ax[0], orientation='horizontal', pad=0.04)
fig.colorbar(im1, ax=ax[1], orientation='horizontal', pad=0.04)
fig.colorbar(im2, ax=ax[2], orientation='horizontal', pad=0.04)
fig.colorbar(im3, ax=ax[3], orientation='horizontal', pad=0.04)
fig.colorbar(im4, ax=ax[4], orientation='horizontal', pad=0.04)
fig.colorbar(im5, ax=ax[5], orientation='horizontal', pad=0.04)
fig.colorbar(im6, ax=ax[6], orientation='horizontal', pad=0.04)

plt.show()


fig, ax = plt.subplots(1,7,figsize=(17,3), constrained_layout=True)

im0=ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
im1=ax[1].imshow(delta_M1, cmap='plasma') 
ax[1].set_title("p=6")
im2=ax[2].imshow(delta_M2, cmap='plasma') 
ax[2].set_title("p=7")
im3=ax[3].imshow(delta_M3, cmap='plasma') 
ax[3].set_title("p=8")
im4=ax[4].imshow(delta_M4, cmap='plasma') 
ax[4].set_title("p=9")
im5=ax[5].imshow(delta_M5, cmap='plasma') 
ax[5].set_title("p=10")
im6=ax[6].imshow(delta_M6, cmap='plasma') 
ax[6].set_title("p=11")


fig.suptitle("$p$ comparison - marked overdensity field")


fig.colorbar(im0, ax=ax[0], orientation='horizontal', pad=0.04)
fig.colorbar(im1, ax=ax[1], orientation='horizontal', pad=0.04)
fig.colorbar(im2, ax=ax[2], orientation='horizontal', pad=0.04)
fig.colorbar(im3, ax=ax[3], orientation='horizontal', pad=0.04)
fig.colorbar(im4, ax=ax[4], orientation='horizontal', pad=0.04)
fig.colorbar(im5, ax=ax[5], orientation='horizontal', pad=0.04)
fig.colorbar(im6, ax=ax[6], orientation='horizontal', pad=0.04)

plt.show()

# %% [markdown]
# ##### universe 2

# %%
# different p values

_, _, _, rho_x = u.load_universe("universe_parameters1.json")

rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m1, delta_M1 = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=6)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m2, delta_M2 = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=7)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m3, delta_M3 = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=8)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m4, delta_M4 = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=9)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m5, delta_M5 = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=10)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m6, delta_M6 = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=11)


# stacked overdensity plots

# stacked mark

fig, ax = plt.subplots(1,7,figsize=(17,3), constrained_layout=True)

im0=ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
im1=ax[1].imshow(m1, cmap='plasma') 
ax[1].set_title("p=6")
im2=ax[2].imshow(m2, cmap='plasma') 
ax[2].set_title("p=7")
im3=ax[3].imshow(m3, cmap='plasma') 
ax[3].set_title("p=8")
im4=ax[4].imshow(m4, cmap='plasma') 
ax[4].set_title("p=9")
im5=ax[5].imshow(m5, cmap='plasma') 
ax[5].set_title("p=10")
im6=ax[6].imshow(m6, cmap='plasma') 
ax[6].set_title("p=11")

fig.suptitle("$p$ comparison - mark function")


fig.colorbar(im0, ax=ax[0], orientation='horizontal', pad=0.04)
fig.colorbar(im1, ax=ax[1], orientation='horizontal', pad=0.04)
fig.colorbar(im2, ax=ax[2], orientation='horizontal', pad=0.04)
fig.colorbar(im3, ax=ax[3], orientation='horizontal', pad=0.04)
fig.colorbar(im4, ax=ax[4], orientation='horizontal', pad=0.04)
fig.colorbar(im5, ax=ax[5], orientation='horizontal', pad=0.04)
fig.colorbar(im6, ax=ax[6], orientation='horizontal', pad=0.04)

plt.savefig("p-mark")
plt.show()


fig, ax = plt.subplots(1,7,figsize=(17,3), constrained_layout=True)

im0=ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
im1=ax[1].imshow(delta_M1, cmap='plasma') 
ax[1].set_title("p=6")
im2=ax[2].imshow(delta_M2, cmap='plasma') 
ax[2].set_title("p=7")
im3=ax[3].imshow(delta_M3, cmap='plasma') 
ax[3].set_title("p=8")
im4=ax[4].imshow(delta_M4, cmap='plasma') 
ax[4].set_title("p=9")
im5=ax[5].imshow(delta_M5, cmap='plasma') 
ax[5].set_title("p=10")
im6=ax[6].imshow(delta_M6, cmap='plasma') 
ax[6].set_title("p=11")


fig.suptitle("$p$ comparison - marked overdensity field")


fig.colorbar(im0, ax=ax[0], orientation='horizontal', pad=0.04)
fig.colorbar(im1, ax=ax[1], orientation='horizontal', pad=0.04)
fig.colorbar(im2, ax=ax[2], orientation='horizontal', pad=0.04)
fig.colorbar(im3, ax=ax[3], orientation='horizontal', pad=0.04)
fig.colorbar(im4, ax=ax[4], orientation='horizontal', pad=0.04)
fig.colorbar(im5, ax=ax[5], orientation='horizontal', pad=0.04)
fig.colorbar(im6, ax=ax[6], orientation='horizontal', pad=0.04)

plt.savefig("p-marked field")
plt.show()

# %% [markdown]
# ##### universe 3

# %%
# different p values

_, _, _, rho_x = u.load_universe("universe_parameters2.json")
rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m1, delta_M1 = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=6)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m2, delta_M2 = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=7)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m3, delta_M3 = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=8)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m4, delta_M4 = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=9)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m5, delta_M5 = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=10)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m6, delta_M6 = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=11)


# stacked overdensity plots

# stacked mark

fig, ax = plt.subplots(1,7,figsize=(17,3), constrained_layout=True)

im0=ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
im1=ax[1].imshow(m1, cmap='plasma') 
ax[1].set_title("p=6")
im2=ax[2].imshow(m2, cmap='plasma') 
ax[2].set_title("p=7")
im3=ax[3].imshow(m3, cmap='plasma') 
ax[3].set_title("p=8")
im4=ax[4].imshow(m4, cmap='plasma') 
ax[4].set_title("p=9")
im5=ax[5].imshow(m5, cmap='plasma') 
ax[5].set_title("p=10")
im6=ax[6].imshow(m6, cmap='plasma') 
ax[6].set_title("p=11")

fig.suptitle("$p$ comparison - mark function")


fig.colorbar(im0, ax=ax[0], orientation='horizontal', pad=0.04)
fig.colorbar(im1, ax=ax[1], orientation='horizontal', pad=0.04)
fig.colorbar(im2, ax=ax[2], orientation='horizontal', pad=0.04)
fig.colorbar(im3, ax=ax[3], orientation='horizontal', pad=0.04)
fig.colorbar(im4, ax=ax[4], orientation='horizontal', pad=0.04)
fig.colorbar(im5, ax=ax[5], orientation='horizontal', pad=0.04)
fig.colorbar(im6, ax=ax[6], orientation='horizontal', pad=0.04)

plt.show()


fig, ax = plt.subplots(1,7,figsize=(17,3), constrained_layout=True)

im0=ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
im1=ax[1].imshow(delta_M1, cmap='plasma') 
ax[1].set_title("p=6")
im2=ax[2].imshow(delta_M2, cmap='plasma') 
ax[2].set_title("p=7")
im3=ax[3].imshow(delta_M3, cmap='plasma') 
ax[3].set_title("p=8")
im4=ax[4].imshow(delta_M4, cmap='plasma') 
ax[4].set_title("p=9")
im5=ax[5].imshow(delta_M5, cmap='plasma') 
ax[5].set_title("p=10")
im6=ax[6].imshow(delta_M6, cmap='plasma') 
ax[6].set_title("p=11")


fig.suptitle("$p$ comparison - marked overdensity field")


fig.colorbar(im0, ax=ax[0], orientation='horizontal', pad=0.04)
fig.colorbar(im1, ax=ax[1], orientation='horizontal', pad=0.04)
fig.colorbar(im2, ax=ax[2], orientation='horizontal', pad=0.04)
fig.colorbar(im3, ax=ax[3], orientation='horizontal', pad=0.04)
fig.colorbar(im4, ax=ax[4], orientation='horizontal', pad=0.04)
fig.colorbar(im5, ax=ax[5], orientation='horizontal', pad=0.04)
fig.colorbar(im6, ax=ax[6], orientation='horizontal', pad=0.04)

plt.show()

# %% [markdown]
# ##### universe 4

# %%
# different p values

_, _, _, rho_x = u.load_universe("universe_parameters3.json")
rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m1, delta_M1 = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=6)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m2, delta_M2 = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=7)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m3, delta_M3 = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=8)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m4, delta_M4 = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=9)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m5, delta_M5 = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=10)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m6, delta_M6 = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=11)


# stacked overdensity plots

# stacked mark

fig, ax = plt.subplots(1,7,figsize=(17,3), constrained_layout=True)

im0=ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
im1=ax[1].imshow(m1, cmap='plasma') 
ax[1].set_title("p=6")
im2=ax[2].imshow(m2, cmap='plasma') 
ax[2].set_title("p=7")
im3=ax[3].imshow(m3, cmap='plasma') 
ax[3].set_title("p=8")
im4=ax[4].imshow(m4, cmap='plasma') 
ax[4].set_title("p=9")
im5=ax[5].imshow(m5, cmap='plasma') 
ax[5].set_title("p=10")
im6=ax[6].imshow(m6, cmap='plasma') 
ax[6].set_title("p=11")

fig.suptitle("$p$ comparison - mark function")


fig.colorbar(im0, ax=ax[0], orientation='horizontal', pad=0.04)
fig.colorbar(im1, ax=ax[1], orientation='horizontal', pad=0.04)
fig.colorbar(im2, ax=ax[2], orientation='horizontal', pad=0.04)
fig.colorbar(im3, ax=ax[3], orientation='horizontal', pad=0.04)
fig.colorbar(im4, ax=ax[4], orientation='horizontal', pad=0.04)
fig.colorbar(im5, ax=ax[5], orientation='horizontal', pad=0.04)
fig.colorbar(im6, ax=ax[6], orientation='horizontal', pad=0.04)

plt.show()


fig, ax = plt.subplots(1,7,figsize=(17,3), constrained_layout=True)

im0=ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
im1=ax[1].imshow(delta_M1, cmap='plasma') 
ax[1].set_title("p=6")
im2=ax[2].imshow(delta_M2, cmap='plasma') 
ax[2].set_title("p=7")
im3=ax[3].imshow(delta_M3, cmap='plasma') 
ax[3].set_title("p=8")
im4=ax[4].imshow(delta_M4, cmap='plasma') 
ax[4].set_title("p=9")
im5=ax[5].imshow(delta_M5, cmap='plasma') 
ax[5].set_title("p=10")
im6=ax[6].imshow(delta_M6, cmap='plasma') 
ax[6].set_title("p=11")


fig.suptitle("$p$ comparison - marked overdensity field")


fig.colorbar(im0, ax=ax[0], orientation='horizontal', pad=0.04)
fig.colorbar(im1, ax=ax[1], orientation='horizontal', pad=0.04)
fig.colorbar(im2, ax=ax[2], orientation='horizontal', pad=0.04)
fig.colorbar(im3, ax=ax[3], orientation='horizontal', pad=0.04)
fig.colorbar(im4, ax=ax[4], orientation='horizontal', pad=0.04)
fig.colorbar(im5, ax=ax[5], orientation='horizontal', pad=0.04)
fig.colorbar(im6, ax=ax[6], orientation='horizontal', pad=0.04)

plt.show()

# %% [markdown]
# ### mark parameter $\delta*$

# %% [markdown]
# ##### universe 1

# %%
# different \delta* values

_, _, _, rho_x = u.load_universe("universe_parameters.json")

rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m0, delta_M0 = u.marked_overdensity_field(delta_x, delta_R, delta_star=2, p=10)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m1, delta_M1 = u.marked_overdensity_field(delta_x, delta_R, delta_star=3, p=10)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m2, delta_M2 = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=10)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m3, delta_M3 = u.marked_overdensity_field(delta_x, delta_R, delta_star=5, p=10)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m4, delta_M4 = u.marked_overdensity_field(delta_x, delta_R, delta_star=6, p=10)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m5, delta_M5 = u.marked_overdensity_field(delta_x, delta_R, delta_star=7, p=10)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m6, delta_M6 = u.marked_overdensity_field(delta_x, delta_R, delta_star=8, p=10)


# stacked overdensity plots

# stacked mark

fig, ax = plt.subplots(1,8,figsize=(20,3), constrained_layout=True)

im0 = ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
im1 = ax[1].imshow(m0, cmap='plasma') 
ax[1].set_title("$\delta*$=2")
im2 = ax[2].imshow(m1, cmap='plasma') 
ax[2].set_title("$\delta*$=3")
im3 = ax[3].imshow(m2, cmap='plasma') 
ax[3].set_title("$\delta*$=4")
im4 = ax[4].imshow(m3, cmap='plasma') 
ax[4].set_title("$\delta*$=5")
im5 = ax[5].imshow(m4, cmap='plasma') 
ax[5].set_title("$\delta*$=6")
im6= ax[6].imshow(m5, cmap='plasma') 
ax[6].set_title("$\delta*$=7")
im7= ax[7].imshow(m6, cmap='plasma') 
ax[7].set_title("$\delta*$=8")



fig.suptitle("$\delta*$ comparison - mark function")

fig.colorbar(im0, ax=ax[0], orientation='horizontal', pad=0.04)
fig.colorbar(im1, ax=ax[1], orientation='horizontal', pad=0.04)
fig.colorbar(im2, ax=ax[2], orientation='horizontal', pad=0.04)
fig.colorbar(im3, ax=ax[3], orientation='horizontal', pad=0.04)
fig.colorbar(im4, ax=ax[4], orientation='horizontal', pad=0.04)
fig.colorbar(im5, ax=ax[5], orientation='horizontal', pad=0.04)
fig.colorbar(im6, ax=ax[6], orientation='horizontal', pad=0.04)
fig.colorbar(im7, ax=ax[7], orientation='horizontal', pad=0.04)


plt.show()


fig, ax = plt.subplots(1,8,figsize=(20,3), constrained_layout=True)

im0 = ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
im1= ax[1].imshow(delta_M0, cmap='plasma') 
ax[1].set_title("$\delta*$=2")
im2 = ax[2].imshow(delta_M1, cmap='plasma') 
ax[2].set_title("$\delta*$=3")
im3= ax[3].imshow(delta_M2, cmap='plasma') 
ax[3].set_title("$\delta*$=4")
im4 = ax[4].imshow(delta_M3, cmap='plasma') 
ax[4].set_title("$\delta*$=5")
im5=ax[5].imshow(delta_M4, cmap='plasma') 
ax[5].set_title("$\delta*$=6")
im6=ax[6].imshow(delta_M5, cmap='plasma') 
ax[6].set_title("$\delta*$=7")
im7 = ax[7].imshow(delta_M6, cmap='plasma') 
ax[7].set_title("$\delta*$=8")

fig.suptitle("$\delta*$ comparison - marked overdensity field")

fig.colorbar(im0, ax=ax[0], orientation='horizontal', pad=0.04)
fig.colorbar(im1, ax=ax[1], orientation='horizontal', pad=0.04)
fig.colorbar(im2, ax=ax[2], orientation='horizontal', pad=0.04)
fig.colorbar(im3, ax=ax[3], orientation='horizontal', pad=0.04)
fig.colorbar(im4, ax=ax[4], orientation='horizontal', pad=0.04)
fig.colorbar(im5, ax=ax[5], orientation='horizontal', pad=0.04)
fig.colorbar(im6, ax=ax[6], orientation='horizontal', pad=0.04)
fig.colorbar(im7, ax=ax[7], orientation='horizontal', pad=0.04)


plt.show()

# %% [markdown]
# ##### universe 2

# %%
# different \delta* values

_, _, _, rho_x = u.load_universe("universe_parameters1.json")


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m0, delta_M0 = u.marked_overdensity_field(delta_x, delta_R, delta_star=2, p=10)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m1, delta_M1 = u.marked_overdensity_field(delta_x, delta_R, delta_star=3, p=10)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m2, delta_M2 = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=10)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m3, delta_M3 = u.marked_overdensity_field(delta_x, delta_R, delta_star=5, p=10)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m4, delta_M4 = u.marked_overdensity_field(delta_x, delta_R, delta_star=6, p=10)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m5, delta_M5 = u.marked_overdensity_field(delta_x, delta_R, delta_star=7, p=10)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m6, delta_M6 = u.marked_overdensity_field(delta_x, delta_R, delta_star=8, p=10)


# stacked overdensity plots

# stacked mark

fig, ax = plt.subplots(1,8,figsize=(20,3), constrained_layout=True)

im0 = ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
im1 = ax[1].imshow(m0, cmap='plasma') 
ax[1].set_title("$\delta*$=2")
im2 = ax[2].imshow(m1, cmap='plasma') 
ax[2].set_title("$\delta*$=3")
im3 = ax[3].imshow(m2, cmap='plasma') 
ax[3].set_title("$\delta*$=4")
im4 = ax[4].imshow(m3, cmap='plasma') 
ax[4].set_title("$\delta*$=5")
im5 = ax[5].imshow(m4, cmap='plasma') 
ax[5].set_title("$\delta*$=6")
im6= ax[6].imshow(m5, cmap='plasma') 
ax[6].set_title("$\delta*$=7")
im7= ax[7].imshow(m6, cmap='plasma') 
ax[7].set_title("$\delta*$=8")



fig.suptitle("$\delta*$ comparison - marked function")

fig.colorbar(im0, ax=ax[0], orientation='horizontal', pad=0.04)
fig.colorbar(im1, ax=ax[1], orientation='horizontal', pad=0.04)
fig.colorbar(im2, ax=ax[2], orientation='horizontal', pad=0.04)
fig.colorbar(im3, ax=ax[3], orientation='horizontal', pad=0.04)
fig.colorbar(im4, ax=ax[4], orientation='horizontal', pad=0.04)
fig.colorbar(im5, ax=ax[5], orientation='horizontal', pad=0.04)
fig.colorbar(im6, ax=ax[6], orientation='horizontal', pad=0.04)
fig.colorbar(im7, ax=ax[7], orientation='horizontal', pad=0.04)


plt.show()


fig, ax = plt.subplots(1,8,figsize=(20,3), constrained_layout=True)

im0 = ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
im1= ax[1].imshow(delta_M0, cmap='plasma') 
ax[1].set_title("$\delta*$=2")
im2 = ax[2].imshow(delta_M1, cmap='plasma') 
ax[2].set_title("$\delta*$=3")
im3= ax[3].imshow(delta_M2, cmap='plasma') 
ax[3].set_title("$\delta*$=4")
im4 = ax[4].imshow(delta_M3, cmap='plasma') 
ax[4].set_title("$\delta*$=5")
im5=ax[5].imshow(delta_M4, cmap='plasma') 
ax[5].set_title("$\delta*$=6")
im6=ax[6].imshow(delta_M5, cmap='plasma') 
ax[6].set_title("$\delta*$=7")
im7 = ax[7].imshow(delta_M6, cmap='plasma') 
ax[7].set_title("$\delta*$=8")

fig.suptitle("$\delta*$ comparison - marked overdensity field")

fig.colorbar(im0, ax=ax[0], orientation='horizontal', pad=0.04)
fig.colorbar(im1, ax=ax[1], orientation='horizontal', pad=0.04)
fig.colorbar(im2, ax=ax[2], orientation='horizontal', pad=0.04)
fig.colorbar(im3, ax=ax[3], orientation='horizontal', pad=0.04)
fig.colorbar(im4, ax=ax[4], orientation='horizontal', pad=0.04)
fig.colorbar(im5, ax=ax[5], orientation='horizontal', pad=0.04)
fig.colorbar(im6, ax=ax[6], orientation='horizontal', pad=0.04)
fig.colorbar(im7, ax=ax[7], orientation='horizontal', pad=0.04)


# plt.tight_layout()
plt.show()

# %% [markdown]
# ##### universe 3

# %%
# different \delta* values

_, _, _, rho_x = u.load_universe("universe_parameters2.json")

rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m0, delta_M0 = u.marked_overdensity_field(delta_x, delta_R, delta_star=2, p=10)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m1, delta_M1 = u.marked_overdensity_field(delta_x, delta_R, delta_star=3, p=10)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m2, delta_M2 = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=10)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m3, delta_M3 = u.marked_overdensity_field(delta_x, delta_R, delta_star=5, p=10)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m4, delta_M4 = u.marked_overdensity_field(delta_x, delta_R, delta_star=6, p=10)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m5, delta_M5 = u.marked_overdensity_field(delta_x, delta_R, delta_star=7, p=10)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m6, delta_M6 = u.marked_overdensity_field(delta_x, delta_R, delta_star=8, p=10)


# stacked overdensity plots

# stacked mark

fig, ax = plt.subplots(1,8,figsize=(20,3), constrained_layout=True)

im0 = ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
im1 = ax[1].imshow(m0, cmap='plasma') 
ax[1].set_title("$\delta*$=2")
im2 = ax[2].imshow(m1, cmap='plasma') 
ax[2].set_title("$\delta*$=3")
im3 = ax[3].imshow(m2, cmap='plasma') 
ax[3].set_title("$\delta*$=4")
im4 = ax[4].imshow(m3, cmap='plasma') 
ax[4].set_title("$\delta*$=5")
im5 = ax[5].imshow(m4, cmap='plasma') 
ax[5].set_title("$\delta*$=6")
im6= ax[6].imshow(m5, cmap='plasma') 
ax[6].set_title("$\delta*$=7")
im7= ax[7].imshow(m6, cmap='plasma') 
ax[7].set_title("$\delta*$=8")



fig.suptitle("$\delta*$ comparison - mark function")

fig.colorbar(im0, ax=ax[0], orientation='horizontal', pad=0.04)
fig.colorbar(im1, ax=ax[1], orientation='horizontal', pad=0.04)
fig.colorbar(im2, ax=ax[2], orientation='horizontal', pad=0.04)
fig.colorbar(im3, ax=ax[3], orientation='horizontal', pad=0.04)
fig.colorbar(im4, ax=ax[4], orientation='horizontal', pad=0.04)
fig.colorbar(im5, ax=ax[5], orientation='horizontal', pad=0.04)
fig.colorbar(im6, ax=ax[6], orientation='horizontal', pad=0.04)
fig.colorbar(im7, ax=ax[7], orientation='horizontal', pad=0.04)


plt.show()


fig, ax = plt.subplots(1,8,figsize=(20,3), constrained_layout=True)

im0 = ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
im1= ax[1].imshow(delta_M0, cmap='plasma') 
ax[1].set_title("$\delta*$=2")
im2 = ax[2].imshow(delta_M1, cmap='plasma') 
ax[2].set_title("$\delta*$=3")
im3= ax[3].imshow(delta_M2, cmap='plasma') 
ax[3].set_title("$\delta*$=4")
im4 = ax[4].imshow(delta_M3, cmap='plasma') 
ax[4].set_title("$\delta*$=5")
im5=ax[5].imshow(delta_M4, cmap='plasma') 
ax[5].set_title("$\delta*$=6")
im6=ax[6].imshow(delta_M5, cmap='plasma') 
ax[6].set_title("$\delta*$=7")
im7 = ax[7].imshow(delta_M6, cmap='plasma') 
ax[7].set_title("$\delta*$=8")

fig.suptitle("$\delta*$ comparison - marked overdensity field")

fig.colorbar(im0, ax=ax[0], orientation='horizontal', pad=0.04)
fig.colorbar(im1, ax=ax[1], orientation='horizontal', pad=0.04)
fig.colorbar(im2, ax=ax[2], orientation='horizontal', pad=0.04)
fig.colorbar(im3, ax=ax[3], orientation='horizontal', pad=0.04)
fig.colorbar(im4, ax=ax[4], orientation='horizontal', pad=0.04)
fig.colorbar(im5, ax=ax[5], orientation='horizontal', pad=0.04)
fig.colorbar(im6, ax=ax[6], orientation='horizontal', pad=0.04)
fig.colorbar(im7, ax=ax[7], orientation='horizontal', pad=0.04)


plt.show()

# %%
# different \delta* values

_, _, _, rho_x = u.load_universe("universe_parameters3.json")


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m0, delta_M0 = u.marked_overdensity_field(delta_x, delta_R, delta_star=2, p=10)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m1, delta_M1 = u.marked_overdensity_field(delta_x, delta_R, delta_star=3, p=10)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m2, delta_M2 = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=10)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m3, delta_M3 = u.marked_overdensity_field(delta_x, delta_R, delta_star=5, p=10)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m4, delta_M4 = u.marked_overdensity_field(delta_x, delta_R, delta_star=6, p=10)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m5, delta_M5 = u.marked_overdensity_field(delta_x, delta_R, delta_star=7, p=10)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m6, delta_M6 = u.marked_overdensity_field(delta_x, delta_R, delta_star=8, p=10)


# stacked overdensity plots

# stacked mark

fig, ax = plt.subplots(1,8,figsize=(20,3), constrained_layout=True)

im0 = ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
im1 = ax[1].imshow(m0, cmap='plasma') 
ax[1].set_title("$\delta*$=2")
im2 = ax[2].imshow(m1, cmap='plasma') 
ax[2].set_title("$\delta*$=3")
im3 = ax[3].imshow(m2, cmap='plasma') 
ax[3].set_title("$\delta*$=4")
im4 = ax[4].imshow(m3, cmap='plasma') 
ax[4].set_title("$\delta*$=5")
im5 = ax[5].imshow(m4, cmap='plasma') 
ax[5].set_title("$\delta*$=6")
im6= ax[6].imshow(m5, cmap='plasma') 
ax[6].set_title("$\delta*$=7")
im7= ax[7].imshow(m6, cmap='plasma') 
ax[7].set_title("$\delta*$=8")



fig.suptitle("$\delta*$ comparison - mark function")

fig.colorbar(im0, ax=ax[0], orientation='horizontal', pad=0.04)
fig.colorbar(im1, ax=ax[1], orientation='horizontal', pad=0.04)
fig.colorbar(im2, ax=ax[2], orientation='horizontal', pad=0.04)
fig.colorbar(im3, ax=ax[3], orientation='horizontal', pad=0.04)
fig.colorbar(im4, ax=ax[4], orientation='horizontal', pad=0.04)
fig.colorbar(im5, ax=ax[5], orientation='horizontal', pad=0.04)
fig.colorbar(im6, ax=ax[6], orientation='horizontal', pad=0.04)
fig.colorbar(im7, ax=ax[7], orientation='horizontal', pad=0.04)

plt.savefig("delta-mark.png")
plt.show()


fig, ax = plt.subplots(1,8,figsize=(20,3), constrained_layout=True)

im0 = ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
im1= ax[1].imshow(delta_M0, cmap='plasma') 
ax[1].set_title("$\delta*$=2")
im2 = ax[2].imshow(delta_M1, cmap='plasma') 
ax[2].set_title("$\delta*$=3")
im3= ax[3].imshow(delta_M2, cmap='plasma') 
ax[3].set_title("$\delta*$=4")
im4 = ax[4].imshow(delta_M3, cmap='plasma') 
ax[4].set_title("$\delta*$=5")
im5=ax[5].imshow(delta_M4, cmap='plasma') 
ax[5].set_title("$\delta*$=6")
im6=ax[6].imshow(delta_M5, cmap='plasma') 
ax[6].set_title("$\delta*$=7")
im7 = ax[7].imshow(delta_M6, cmap='plasma') 
ax[7].set_title("$\delta*$=8")

fig.suptitle("$\delta*$ comparison - marked overdensity field")

fig.colorbar(im0, ax=ax[0], orientation='horizontal', pad=0.04)
fig.colorbar(im1, ax=ax[1], orientation='horizontal', pad=0.04)
fig.colorbar(im2, ax=ax[2], orientation='horizontal', pad=0.04)
fig.colorbar(im3, ax=ax[3], orientation='horizontal', pad=0.04)
fig.colorbar(im4, ax=ax[4], orientation='horizontal', pad=0.04)
fig.colorbar(im5, ax=ax[5], orientation='horizontal', pad=0.04)
fig.colorbar(im6, ax=ax[6], orientation='horizontal', pad=0.04)
fig.colorbar(im7, ax=ax[7], orientation='horizontal', pad=0.04)

plt.savefig("delta-marked-field.png")
plt.show()
