# %%
import model_universe_2d as u
import matplotlib.pyplot as plt

# %% [markdown]
# > need to experiment with more parameters for $p$ and $\delta*$, unsure now

# %% [markdown]
# #### default visualization

# %% [markdown]
# default parameters: $\delta* = 10$ and $p=7$, $R=3$

# %%
# density fields - aviles's parameters
rho_x = u.rho_x  # tracer density field 
rho_R = u.rho_R # smoothed density tracer field
delta_x = u.delta_x # overdensity of tracer field
delta_R = u.delta_R # overdensity of downsampled tracer field
m = u.m # mark
delta_M = u.delta_M # marked density field

u.plot_heatmap(rho_x, 'original density field')

# %% [markdown]
# original marked field

# %%
u.plot_heatmap(delta_M, 'marked field p=7, d_star=10, R=3')

# %% [markdown]
# alternative parameters: $\delta* = 4$ and $p=10$

# %%
rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m, delta_M = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=10)

# plot ================================================
# u.plot_heatmap(delta_R, 'smoothed')
# u.plot_heatmap(m, 'mark')
u.plot_heatmap(delta_M, 'marked field p=4, d_star=10, R=3')

# %% [markdown]
# a different $R$ value

# %%
rho_R = u.gaussian_filter(rho_x, R=6)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m, delta_M = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=10)

# plot marked field
u.plot_heatmap(delta_M, 'marked field p=4, d_star=10')

# %% [markdown]
# ### testing R values

# %% [markdown]
# <div style="padding: 15px; border: 1px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #31708f; background-color: #d9edf7; border-color: #bce8f1;">
#
# Best parameter so far appearssto be $R=3$
# </div>

# %% [markdown]
# ##### universe 1

# %%
# different R values

rho_R = u.gaussian_filter(rho_x, R=1)
delta_x = u.overdensity_field(rho_x)
delta_R1 = u.overdensity_field(rho_R)
m1, delta_M1 = u.marked_overdensity_field(delta_x, delta_R1, delta_star=4, p=10)


rho_R = u.gaussian_filter(rho_x, R=2)
delta_x = u.overdensity_field(rho_x)
delta_R2 = u.overdensity_field(rho_R)
m2, delta_M2 = u.marked_overdensity_field(delta_x, delta_R2, delta_star=4, p=10)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R3 = u.overdensity_field(rho_R)
m3, delta_M3 = u.marked_overdensity_field(delta_x, delta_R3, delta_star=4, p=10)


rho_R = u.gaussian_filter(rho_x, R=4)
delta_x = u.overdensity_field(rho_x)
delta_R4 = u.overdensity_field(rho_R)
m4, delta_M4 = u.marked_overdensity_field(delta_x, delta_R4, delta_star=4, p=10)

rho_R = u.gaussian_filter(rho_x, R=5)
delta_x = u.overdensity_field(rho_x)
delta_R5 = u.overdensity_field(rho_R)
m5, delta_M5 = u.marked_overdensity_field(delta_x, delta_R4, delta_star=4, p=10)


# stacked overdensity plots
fig, ax = plt.subplots(1,6,figsize=(10,8))

ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
ax[1].imshow(delta_R1, cmap='plasma') 
ax[1].set_title("R=1")
ax[2].imshow(delta_R2, cmap='plasma') 
ax[2].set_title("R=2")
ax[3].imshow(delta_R3, cmap='plasma') 
ax[3].set_title("R=3")
ax[4].imshow(delta_R4, cmap='plasma') 
ax[4].set_title("R=4")
ax[5].imshow(delta_R5, cmap='plasma') 
ax[5].set_title("R=5")


plt.tight_layout()
plt.show()


# stacked mark

fig, ax = plt.subplots(1,6,figsize=(10,8))


ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
ax[1].imshow(m1, cmap='plasma') 
ax[1].set_title("R=1")
ax[2].imshow(m2, cmap='plasma') 
ax[2].set_title("R=2")
ax[3].imshow(m3, cmap='plasma') 
ax[3].set_title("R=3")
ax[4].imshow(m4, cmap='plasma') 
ax[4].set_title("R=4")
ax[5].imshow(m5, cmap='plasma') 
ax[5].set_title("R=5")


plt.tight_layout()
plt.show()


# stacked marked field

fig, ax = plt.subplots(1,6,figsize=(10,8))


ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
ax[1].imshow(delta_M1, cmap='plasma') 
ax[1].set_title("R=1")
ax[2].imshow(delta_M2, cmap='plasma') 
ax[2].set_title("R=2")
ax[3].imshow(delta_M3, cmap='plasma') 
ax[3].set_title("R=3")
ax[4].imshow(delta_M4, cmap='plasma') 
ax[4].set_title("R=4")
ax[5].imshow(delta_M5, cmap='plasma') 
ax[5].set_title("R=5")


plt.tight_layout()
plt.show()

# %% [markdown]
# comparing R values

# %% [markdown]
# ##### universe 2

# %%
# different R values
_, _, _, rho_x = u.load_universe("universe_parameters1.json")

rho_R = u.gaussian_filter(rho_x, R=1)
delta_x = u.overdensity_field(rho_x)
delta_R1 = u.overdensity_field(rho_R)
m1, delta_M1 = u.marked_overdensity_field(delta_x, delta_R1, delta_star=4, p=10)


rho_R = u.gaussian_filter(rho_x, R=2)
delta_x = u.overdensity_field(rho_x)
delta_R2 = u.overdensity_field(rho_R)
m2, delta_M2 = u.marked_overdensity_field(delta_x, delta_R2, delta_star=4, p=10)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R3 = u.overdensity_field(rho_R)
m3, delta_M3 = u.marked_overdensity_field(delta_x, delta_R3, delta_star=4, p=10)


rho_R = u.gaussian_filter(rho_x, R=4)
delta_x = u.overdensity_field(rho_x)
delta_R4 = u.overdensity_field(rho_R)
m4, delta_M4 = u.marked_overdensity_field(delta_x, delta_R4, delta_star=4, p=10)

rho_R = u.gaussian_filter(rho_x, R=5)
delta_x = u.overdensity_field(rho_x)
delta_R5 = u.overdensity_field(rho_R)
m5, delta_M5 = u.marked_overdensity_field(delta_x, delta_R4, delta_star=4, p=10)



# stacked overdensity plots
fig, ax = plt.subplots(1,6,figsize=(10,8))

ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
ax[1].imshow(delta_R1, cmap='plasma') 
ax[1].set_title("R=1")
ax[2].imshow(delta_R2, cmap='plasma') 
ax[2].set_title("R=2")
ax[3].imshow(delta_R3, cmap='plasma') 
ax[3].set_title("R=3")
ax[4].imshow(delta_R4, cmap='plasma') 
ax[4].set_title("R=4")
ax[5].imshow(delta_R5, cmap='plasma') 
ax[5].set_title("R=5")


plt.tight_layout()
plt.show()


# stacked mark

fig, ax = plt.subplots(1,6,figsize=(10,8))


ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
ax[1].imshow(m1, cmap='plasma') 
ax[1].set_title("R=1")
ax[2].imshow(m2, cmap='plasma') 
ax[2].set_title("R=2")
ax[3].imshow(m3, cmap='plasma') 
ax[3].set_title("R=3")
ax[4].imshow(m4, cmap='plasma') 
ax[4].set_title("R=4")
ax[5].imshow(m5, cmap='plasma') 
ax[5].set_title("R=5")


plt.tight_layout()
plt.show()


# stacked marked field

fig, ax = plt.subplots(1,6,figsize=(10,8))


ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
ax[1].imshow(delta_M1, cmap='plasma') 
ax[1].set_title("R=1")
ax[2].imshow(delta_M2, cmap='plasma') 
ax[2].set_title("R=2")
ax[3].imshow(delta_M3, cmap='plasma') 
ax[3].set_title("R=3")
ax[4].imshow(delta_M4, cmap='plasma') 
ax[4].set_title("R=4")
ax[5].imshow(delta_M5, cmap='plasma') 
ax[5].set_title("R=5")


plt.tight_layout()
plt.show()

# %% [markdown]
# ##### universe 3

# %%
# different R values
_, _, _, rho_x = u.load_universe("universe_parameters2.json")

rho_R = u.gaussian_filter(rho_x, R=1)
delta_x = u.overdensity_field(rho_x)
delta_R1 = u.overdensity_field(rho_R)
m1, delta_M1 = u.marked_overdensity_field(delta_x, delta_R1, delta_star=4, p=10)


rho_R = u.gaussian_filter(rho_x, R=2)
delta_x = u.overdensity_field(rho_x)
delta_R2 = u.overdensity_field(rho_R)
m2, delta_M2 = u.marked_overdensity_field(delta_x, delta_R2, delta_star=4, p=10)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R3 = u.overdensity_field(rho_R)
m3, delta_M3 = u.marked_overdensity_field(delta_x, delta_R3, delta_star=4, p=10)


rho_R = u.gaussian_filter(rho_x, R=4)
delta_x = u.overdensity_field(rho_x)
delta_R4 = u.overdensity_field(rho_R)
m4, delta_M4 = u.marked_overdensity_field(delta_x, delta_R4, delta_star=4, p=10)

rho_R = u.gaussian_filter(rho_x, R=5)
delta_x = u.overdensity_field(rho_x)
delta_R5 = u.overdensity_field(rho_R)
m5, delta_M5 = u.marked_overdensity_field(delta_x, delta_R4, delta_star=4, p=10)



# stacked overdensity plots
fig, ax = plt.subplots(1,6,figsize=(10,8))

ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
ax[1].imshow(delta_R1, cmap='plasma') 
ax[1].set_title("R=1")
ax[2].imshow(delta_R2, cmap='plasma') 
ax[2].set_title("R=2")
ax[3].imshow(delta_R3, cmap='plasma') 
ax[3].set_title("R=3")
ax[4].imshow(delta_R4, cmap='plasma') 
ax[4].set_title("R=4")
ax[5].imshow(delta_R5, cmap='plasma') 
ax[5].set_title("R=5")


plt.tight_layout()
plt.show()


# stacked mark

fig, ax = plt.subplots(1,6,figsize=(10,8))


ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
ax[1].imshow(m1, cmap='plasma') 
ax[1].set_title("R=1")
ax[2].imshow(m2, cmap='plasma') 
ax[2].set_title("R=2")
ax[3].imshow(m3, cmap='plasma') 
ax[3].set_title("R=3")
ax[4].imshow(m4, cmap='plasma') 
ax[4].set_title("R=4")
ax[5].imshow(m5, cmap='plasma') 
ax[5].set_title("R=5")


plt.tight_layout()
plt.show()

# stacked marked field

fig, ax = plt.subplots(1,6,figsize=(10,8))


ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
ax[1].imshow(delta_M1, cmap='plasma') 
ax[1].set_title("R=1")
ax[2].imshow(delta_M2, cmap='plasma') 
ax[2].set_title("R=2")
ax[3].imshow(delta_M3, cmap='plasma') 
ax[3].set_title("R=3")
ax[4].imshow(delta_M4, cmap='plasma') 
ax[4].set_title("R=4")
ax[5].imshow(delta_M5, cmap='plasma') 
ax[5].set_title("R=5")


plt.tight_layout()
plt.show()

# %% [markdown]
# ##### universe 4

# %%
# different R values
_, _, _, rho_x = u.load_universe("universe_parameters3.json")

rho_R = u.gaussian_filter(rho_x, R=1)
delta_x = u.overdensity_field(rho_x)
delta_R1 = u.overdensity_field(rho_R)
m1, delta_M1 = u.marked_overdensity_field(delta_x, delta_R1, delta_star=4, p=10)


rho_R = u.gaussian_filter(rho_x, R=2)
delta_x = u.overdensity_field(rho_x)
delta_R2 = u.overdensity_field(rho_R)
m2, delta_M2 = u.marked_overdensity_field(delta_x, delta_R2, delta_star=4, p=10)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R3 = u.overdensity_field(rho_R)
m3, delta_M3 = u.marked_overdensity_field(delta_x, delta_R3, delta_star=4, p=10)


rho_R = u.gaussian_filter(rho_x, R=4)
delta_x = u.overdensity_field(rho_x)
delta_R4 = u.overdensity_field(rho_R)
m4, delta_M4 = u.marked_overdensity_field(delta_x, delta_R4, delta_star=4, p=10)

rho_R = u.gaussian_filter(rho_x, R=5)
delta_x = u.overdensity_field(rho_x)
delta_R5 = u.overdensity_field(rho_R)
m5, delta_M5 = u.marked_overdensity_field(delta_x, delta_R4, delta_star=4, p=10)



# stacked overdensity plots
fig, ax = plt.subplots(1,6,figsize=(10,8))

ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
ax[1].imshow(delta_R1, cmap='plasma') 
ax[1].set_title("R=1")
ax[2].imshow(delta_R2, cmap='plasma') 
ax[2].set_title("R=2")
ax[3].imshow(delta_R3, cmap='plasma') 
ax[3].set_title("R=3")
ax[4].imshow(delta_R4, cmap='plasma') 
ax[4].set_title("R=4")
ax[5].imshow(delta_R5, cmap='plasma') 
ax[5].set_title("R=5")


plt.tight_layout()
plt.show()


# stacked mark

fig, ax = plt.subplots(1,6,figsize=(10,8))


ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
ax[1].imshow(m1, cmap='plasma') 
ax[1].set_title("R=1")
ax[2].imshow(m2, cmap='plasma') 
ax[2].set_title("R=2")
ax[3].imshow(m3, cmap='plasma') 
ax[3].set_title("R=3")
ax[4].imshow(m4, cmap='plasma') 
ax[4].set_title("R=4")
ax[5].imshow(m5, cmap='plasma') 
ax[5].set_title("R=5")


plt.tight_layout()
plt.show()


# stacked marked field

fig, ax = plt.subplots(1,6,figsize=(10,8))


ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
ax[1].imshow(delta_M1, cmap='plasma') 
ax[1].set_title("R=1")
ax[2].imshow(delta_M2, cmap='plasma') 
ax[2].set_title("R=2")
ax[3].imshow(delta_M3, cmap='plasma') 
ax[3].set_title("R=3")
ax[4].imshow(delta_M4, cmap='plasma') 
ax[4].set_title("R=4")
ax[5].imshow(delta_M5, cmap='plasma') 
ax[5].set_title("R=5")


plt.tight_layout()
plt.show()

# %% [markdown]
# ### mark parameter $p$

# %% [markdown]
# <div style="padding: 15px; border: 1px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #31708f; background-color: #d9edf7; border-color: #bce8f1;">
#
# best parameter so far appears to be $p=7$
# </div>

# %% [markdown]
# ##### universe 1

# %%
# different p values

_, _, _, rho_x = u.load_universe("universe_parameters.json")

rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m1, delta_M1 = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=6)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m2, delta_M2 = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=7)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m3, delta_M3 = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=8)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m4, delta_M4 = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=9)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m5, delta_M5 = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=10)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m6, delta_M6 = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=11)


# stacked overdensity plots

# stacked mark

fig, ax = plt.subplots(1,7,figsize=(10,8))

ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
ax[1].imshow(m1, cmap='plasma') 
ax[1].set_title("p=6")
ax[2].imshow(m2, cmap='plasma') 
ax[2].set_title("p=7")
ax[3].imshow(m3, cmap='plasma') 
ax[3].set_title("p=8")
ax[4].imshow(m4, cmap='plasma') 
ax[4].set_title("p=9")
ax[5].imshow(m5, cmap='plasma') 
ax[5].set_title("p=10")
ax[6].imshow(m6, cmap='plasma') 
ax[6].set_title("p=11")


plt.tight_layout()
plt.show()


fig, ax = plt.subplots(1,7,figsize=(10,8))

ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
ax[1].imshow(delta_M1, cmap='plasma') 
ax[1].set_title("p=6")
ax[2].imshow(delta_M2, cmap='plasma') 
ax[2].set_title("p=7")
ax[3].imshow(delta_M3, cmap='plasma') 
ax[3].set_title("p=8")
ax[4].imshow(delta_M4, cmap='plasma') 
ax[4].set_title("p=9")
ax[5].imshow(delta_M5, cmap='plasma') 
ax[5].set_title("p=10")
ax[6].imshow(delta_M6, cmap='plasma') 
ax[6].set_title("p=11")


plt.tight_layout()
plt.show()

# %% [markdown]
# ##### universe 2

# %%
# different p values

_, _, _, rho_x = u.load_universe("universe_parameters1.json")

rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m1, delta_M1 = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=6)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m2, delta_M2 = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=7)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m3, delta_M3 = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=8)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m4, delta_M4 = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=9)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m5, delta_M5 = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=10)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m6, delta_M6 = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=11)


# stacked overdensity plots

# stacked mark

fig, ax = plt.subplots(1,7,figsize=(10,8))

ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
ax[1].imshow(m1, cmap='plasma') 
ax[1].set_title("p=6")
ax[2].imshow(m2, cmap='plasma') 
ax[2].set_title("p=7")
ax[3].imshow(m3, cmap='plasma') 
ax[3].set_title("p=8")
ax[4].imshow(m4, cmap='plasma') 
ax[4].set_title("p=9")
ax[5].imshow(m5, cmap='plasma') 
ax[5].set_title("p=10")
ax[6].imshow(m6, cmap='plasma') 
ax[6].set_title("p=11")


plt.tight_layout()
plt.show()


fig, ax = plt.subplots(1,7,figsize=(10,8))

ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
ax[1].imshow(delta_M1, cmap='plasma') 
ax[1].set_title("p=6")
ax[2].imshow(delta_M2, cmap='plasma') 
ax[2].set_title("p=7")
ax[3].imshow(delta_M3, cmap='plasma') 
ax[3].set_title("p=8")
ax[4].imshow(delta_M4, cmap='plasma') 
ax[4].set_title("p=9")
ax[5].imshow(delta_M5, cmap='plasma') 
ax[5].set_title("p=10")
ax[6].imshow(delta_M6, cmap='plasma') 
ax[6].set_title("p=11")


plt.tight_layout()
plt.show()

# %% [markdown]
# ##### universe 3

# %%
# different p values

_, _, _, rho_x = u.load_universe("universe_parameters2.json")

rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R1 = u.overdensity_field(rho_R)
m1, delta_M1 = u.marked_overdensity_field(delta_x, delta_R1, delta_star=4, p=6)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m2, delta_M2 = u.marked_overdensity_field(delta_x, delta_R1, delta_star=4, p=7)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m3, delta_M3 = u.marked_overdensity_field(delta_x, delta_R2, delta_star=4, p=8)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m4, delta_M4 = u.marked_overdensity_field(delta_x, delta_R3, delta_star=4, p=9)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m5, delta_M5 = u.marked_overdensity_field(delta_x, delta_R4, delta_star=4, p=10)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m6, delta_M6 = u.marked_overdensity_field(delta_x, delta_R4, delta_star=4, p=11)


# stacked overdensity plots

# stacked mark

fig, ax = plt.subplots(1,7,figsize=(10,8))

ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
ax[1].imshow(m1, cmap='plasma') 
ax[1].set_title("p=6")
ax[2].imshow(m2, cmap='plasma') 
ax[2].set_title("p=7")
ax[3].imshow(m3, cmap='plasma') 
ax[3].set_title("p=8")
ax[4].imshow(m4, cmap='plasma') 
ax[4].set_title("p=9")
ax[5].imshow(m5, cmap='plasma') 
ax[5].set_title("p=10")
ax[6].imshow(m6, cmap='plasma') 
ax[6].set_title("p=11")


plt.tight_layout()
plt.show()


fig, ax = plt.subplots(1,7,figsize=(10,8))

ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
ax[1].imshow(delta_M1, cmap='plasma') 
ax[1].set_title("p=6")
ax[2].imshow(delta_M2, cmap='plasma') 
ax[2].set_title("p=7")
ax[3].imshow(delta_M3, cmap='plasma') 
ax[3].set_title("p=8")
ax[4].imshow(delta_M4, cmap='plasma') 
ax[4].set_title("p=9")
ax[5].imshow(delta_M5, cmap='plasma') 
ax[5].set_title("p=10")
ax[6].imshow(delta_M6, cmap='plasma') 
ax[6].set_title("p=11")


plt.tight_layout()
plt.show()

# %% [markdown]
# ##### universe 4

# %%
# different p values

_, _, _, rho_x = u.load_universe("universe_parameters3.json")

rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R1 = u.overdensity_field(rho_R)
m1, delta_M1 = u.marked_overdensity_field(delta_x, delta_R1, delta_star=4, p=6)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m2, delta_M2 = u.marked_overdensity_field(delta_x, delta_R1, delta_star=4, p=7)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m3, delta_M3 = u.marked_overdensity_field(delta_x, delta_R2, delta_star=4, p=8)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m4, delta_M4 = u.marked_overdensity_field(delta_x, delta_R3, delta_star=4, p=9)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m5, delta_M5 = u.marked_overdensity_field(delta_x, delta_R4, delta_star=4, p=10)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m6, delta_M6 = u.marked_overdensity_field(delta_x, delta_R4, delta_star=4, p=11)


# stacked overdensity plots

# stacked mark

fig, ax = plt.subplots(1,7,figsize=(10,8))

ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
ax[1].imshow(m1, cmap='plasma') 
ax[1].set_title("p=6")
ax[2].imshow(m2, cmap='plasma') 
ax[2].set_title("p=7")
ax[3].imshow(m3, cmap='plasma') 
ax[3].set_title("p=8")
ax[4].imshow(m4, cmap='plasma') 
ax[4].set_title("p=9")
ax[5].imshow(m5, cmap='plasma') 
ax[5].set_title("p=10")
ax[6].imshow(m6, cmap='plasma') 
ax[6].set_title("p=11")


plt.tight_layout()
plt.show()


fig, ax = plt.subplots(1,7,figsize=(10,8))

ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
ax[1].imshow(delta_M1, cmap='plasma') 
ax[1].set_title("p=6")
ax[2].imshow(delta_M2, cmap='plasma') 
ax[2].set_title("p=7")
ax[3].imshow(delta_M3, cmap='plasma') 
ax[3].set_title("p=8")
ax[4].imshow(delta_M4, cmap='plasma') 
ax[4].set_title("p=9")
ax[5].imshow(delta_M5, cmap='plasma') 
ax[5].set_title("p=10")
ax[6].imshow(delta_M6, cmap='plasma') 
ax[6].set_title("p=11")


plt.tight_layout()
plt.show()

# %% [markdown]
# ### mark parameter $\delta*$

# %% [markdown]
# <div style="padding: 15px; border: 1px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #31708f; background-color: #d9edf7; border-color: #bce8f1;">
#
# best parameter so far appears to be $\delta*=4$
# </div>

# %% [markdown]
# ##### universe 1

# %%
# different \delta* values

_, _, _, rho_x = u.load_universe("universe_parameters.json")

rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m0, delta_M0 = u.marked_overdensity_field(delta_x, delta_R, delta_star=2, p=7)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m1, delta_M1 = u.marked_overdensity_field(delta_x, delta_R, delta_star=3, p=7)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m2, delta_M2 = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=7)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m3, delta_M3 = u.marked_overdensity_field(delta_x, delta_R, delta_star=5, p=7)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m4, delta_M4 = u.marked_overdensity_field(delta_x, delta_R, delta_star=6, p=7)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m5, delta_M5 = u.marked_overdensity_field(delta_x, delta_R, delta_star=7, p=7)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m6, delta_M6 = u.marked_overdensity_field(delta_x, delta_R, delta_star=8, p=7)


# stacked overdensity plots

# stacked mark

fig, ax = plt.subplots(1,8,figsize=(10,8))

ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
ax[1].imshow(m1, cmap='plasma') 
ax[1].set_title("delta*=3")
ax[2].imshow(m2, cmap='plasma') 
ax[2].set_title("delta*=4")
ax[3].imshow(m3, cmap='plasma') 
ax[3].set_title("delta*=5")
ax[4].imshow(m4, cmap='plasma') 
ax[4].set_title("delta*=6")
ax[5].imshow(m5, cmap='plasma') 
ax[5].set_title("delta*=7")
ax[6].imshow(m6, cmap='plasma') 
ax[6].set_title("delta*=8")
ax[7].imshow(m0, cmap='plasma') 
ax[7].set_title("delta*=2")


plt.tight_layout()
plt.show()


fig, ax = plt.subplots(1,8,figsize=(10,8))

ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
ax[1].imshow(delta_M1, cmap='plasma') 
ax[1].set_title("delta*=3")
ax[2].imshow(delta_M2, cmap='plasma') 
ax[2].set_title("delta*=4")
ax[3].imshow(delta_M3, cmap='plasma') 
ax[3].set_title("delta*=5")
ax[4].imshow(delta_M4, cmap='plasma') 
ax[4].set_title("delta*=6")
ax[5].imshow(delta_M5, cmap='plasma') 
ax[5].set_title("delta*=7")
ax[6].imshow(delta_M6, cmap='plasma') 
ax[6].set_title("delta*=8")
ax[7].imshow(delta_M0, cmap='plasma') 
ax[7].set_title("delta*=2")


plt.tight_layout()
plt.show()

# %% [markdown]
# ##### universe 2

# %%
# different \delta* values

_, _, _, rho_x = u.load_universe("universe_parameters1.json")

rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m0, delta_M0 = u.marked_overdensity_field(delta_x, delta_R, delta_star=2, p=7)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m1, delta_M1 = u.marked_overdensity_field(delta_x, delta_R, delta_star=3, p=7)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m2, delta_M2 = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=7)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m3, delta_M3 = u.marked_overdensity_field(delta_x, delta_R, delta_star=5, p=7)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m4, delta_M4 = u.marked_overdensity_field(delta_x, delta_R, delta_star=6, p=7)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m5, delta_M5 = u.marked_overdensity_field(delta_x, delta_R, delta_star=7, p=7)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m6, delta_M6 = u.marked_overdensity_field(delta_x, delta_R, delta_star=8, p=7)


# stacked overdensity plots

# stacked mark

fig, ax = plt.subplots(1,8,figsize=(10,8))

ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
ax[1].imshow(m1, cmap='plasma') 
ax[1].set_title("delta*=3")
ax[2].imshow(m2, cmap='plasma') 
ax[2].set_title("delta*=4")
ax[3].imshow(m3, cmap='plasma') 
ax[3].set_title("delta*=5")
ax[4].imshow(m4, cmap='plasma') 
ax[4].set_title("delta*=6")
ax[5].imshow(m5, cmap='plasma') 
ax[5].set_title("delta*=7")
ax[6].imshow(m6, cmap='plasma') 
ax[6].set_title("delta*=8")
ax[7].imshow(m0, cmap='plasma') 
ax[7].set_title("delta*=2")


plt.tight_layout()
plt.show()


fig, ax = plt.subplots(1,8,figsize=(10,8))

ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
ax[1].imshow(delta_M1, cmap='plasma') 
ax[1].set_title("delta*=3")
ax[2].imshow(delta_M2, cmap='plasma') 
ax[2].set_title("delta*=4")
ax[3].imshow(delta_M3, cmap='plasma') 
ax[3].set_title("delta*=5")
ax[4].imshow(delta_M4, cmap='plasma') 
ax[4].set_title("delta*=6")
ax[5].imshow(delta_M5, cmap='plasma') 
ax[5].set_title("delta*=7")
ax[6].imshow(delta_M6, cmap='plasma') 
ax[6].set_title("delta*=8")
ax[7].imshow(delta_M0, cmap='plasma') 
ax[7].set_title("delta*=2")


plt.tight_layout()
plt.show()

# %% [markdown]
# ##### universe 3

# %%
# different \delta* values

_, _, _, rho_x = u.load_universe("universe_parameters2.json")


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m0, delta_M0 = u.marked_overdensity_field(delta_x, delta_R, delta_star=2, p=7)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m1, delta_M1 = u.marked_overdensity_field(delta_x, delta_R, delta_star=3, p=7)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m2, delta_M2 = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=7)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m3, delta_M3 = u.marked_overdensity_field(delta_x, delta_R, delta_star=5, p=7)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m4, delta_M4 = u.marked_overdensity_field(delta_x, delta_R, delta_star=6, p=7)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m5, delta_M5 = u.marked_overdensity_field(delta_x, delta_R, delta_star=7, p=7)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m6, delta_M6 = u.marked_overdensity_field(delta_x, delta_R, delta_star=8, p=7)


# stacked overdensity plots

# stacked mark

fig, ax = plt.subplots(1,8,figsize=(10,8))

ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
ax[1].imshow(m1, cmap='plasma') 
ax[1].set_title("delta*=3")
ax[2].imshow(m2, cmap='plasma') 
ax[2].set_title("delta*=4")
ax[3].imshow(m3, cmap='plasma') 
ax[3].set_title("delta*=5")
ax[4].imshow(m4, cmap='plasma') 
ax[4].set_title("delta*=6")
ax[5].imshow(m5, cmap='plasma') 
ax[5].set_title("delta*=7")
ax[6].imshow(m6, cmap='plasma') 
ax[6].set_title("delta*=8")
ax[7].imshow(m0, cmap='plasma') 
ax[7].set_title("delta*=2")


plt.tight_layout()
plt.show()


fig, ax = plt.subplots(1,8,figsize=(10,8))

ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
ax[1].imshow(delta_M1, cmap='plasma') 
ax[1].set_title("delta*=3")
ax[2].imshow(delta_M2, cmap='plasma') 
ax[2].set_title("delta*=4")
ax[3].imshow(delta_M3, cmap='plasma') 
ax[3].set_title("delta*=5")
ax[4].imshow(delta_M4, cmap='plasma') 
ax[4].set_title("delta*=6")
ax[5].imshow(delta_M5, cmap='plasma') 
ax[5].set_title("delta*=7")
ax[6].imshow(delta_M6, cmap='plasma') 
ax[6].set_title("delta*=8")
ax[7].imshow(delta_M0, cmap='plasma') 
ax[7].set_title("delta*=2")


plt.tight_layout()
plt.show()

# %%
# different \delta* values

_, _, _, rho_x = u.load_universe("universe_parameters3.json")

rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m0, delta_M0 = u.marked_overdensity_field(delta_x, delta_R, delta_star=2, p=7)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m1, delta_M1 = u.marked_overdensity_field(delta_x, delta_R, delta_star=3, p=7)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m2, delta_M2 = u.marked_overdensity_field(delta_x, delta_R, delta_star=4, p=7)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m3, delta_M3 = u.marked_overdensity_field(delta_x, delta_R, delta_star=5, p=7)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m4, delta_M4 = u.marked_overdensity_field(delta_x, delta_R, delta_star=6, p=7)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m5, delta_M5 = u.marked_overdensity_field(delta_x, delta_R, delta_star=7, p=7)


rho_R = u.gaussian_filter(rho_x, R=3)
delta_x = u.overdensity_field(rho_x)
delta_R = u.overdensity_field(rho_R)
m6, delta_M6 = u.marked_overdensity_field(delta_x, delta_R, delta_star=8, p=7)


# stacked overdensity plots

# stacked mark

fig, ax = plt.subplots(1,8,figsize=(10,8))

ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
ax[1].imshow(m1, cmap='plasma') 
ax[1].set_title("delta*=3")
ax[2].imshow(m2, cmap='plasma') 
ax[2].set_title("delta*=4")
ax[3].imshow(m3, cmap='plasma') 
ax[3].set_title("delta*=5")
ax[4].imshow(m4, cmap='plasma') 
ax[4].set_title("delta*=6")
ax[5].imshow(m5, cmap='plasma') 
ax[5].set_title("delta*=7")
ax[6].imshow(m6, cmap='plasma') 
ax[6].set_title("delta*=8")
ax[7].imshow(m0, cmap='plasma') 
ax[7].set_title("delta*=2")


plt.tight_layout()
plt.show()


fig, ax = plt.subplots(1,8,figsize=(10,8))

ax[0].imshow(delta_x, cmap='plasma') 
ax[0].set_title("original")
ax[1].imshow(delta_M1, cmap='plasma') 
ax[1].set_title("delta*=3")
ax[2].imshow(delta_M2, cmap='plasma') 
ax[2].set_title("delta*=4")
ax[3].imshow(delta_M3, cmap='plasma') 
ax[3].set_title("delta*=5")
ax[4].imshow(delta_M4, cmap='plasma') 
ax[4].set_title("delta*=6")
ax[5].imshow(delta_M5, cmap='plasma') 
ax[5].set_title("delta*=7")
ax[6].imshow(delta_M6, cmap='plasma') 
ax[6].set_title("delta*=8")
ax[7].imshow(delta_M0, cmap='plasma') 
ax[7].set_title("delta*=2")


plt.tight_layout()
plt.show()

# %% [markdown]
# ### residual plots

# %%
# aviles's parameters


# my parameters -- set 1 


# my parameters -- set 2


# my parameters -- set 3
